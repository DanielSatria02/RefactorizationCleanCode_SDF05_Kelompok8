# %%
def f(a, b, c, d, e):
    x = a * b
    S = 0
    for i in c:
        S = S + i
    if s > 100:
        x = x * 0.9
    else:
        x = x * 0.95
    t = 0
    for i in c:
        t = t + i
    if d:
        X = X + 0
    else:
        X = X + e
    return x

# %%
# minimal change was made in order for this to work
def f(a, b, c, d, e):
    x = a * b
    S = 0
    for i in c:
        S = S + i
    if S > 100:
        x = x * 0.9
    else:
        x = x * 0.95
    t = 0
    for i in c:
        t = t + i
    if d:
        x = x + 0
    else:
        x = x + e
    return x


# Enter test values when you run this cell.
a = float(input("Individual price: "))
b = float(input("Quantity: "))
c = [float(value) for value in input("Values for c, separated by spaces: ").split()]
d = input("Is the customer a member? (yes/no): ").strip().lower() == "yes"
e = float(input("Shipping fee: "))

print("Order total:", f(a, b, c, d, e))
# Out:
# Order total: 100950.0
