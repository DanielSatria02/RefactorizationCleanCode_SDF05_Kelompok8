# %%
def f(a, b, c, d, e):
    x = a * b
    S = 0
    for i in c:
        S= S + i
    if s > 100:
        x = x * 0.9
    else:
        x = x * 0.95
    t = 0
    for i in c:
        t = t +i
    if d:
        X = X + 0
    else:
        X = X+ e
    return x
